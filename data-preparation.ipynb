# %% [markdown]
# #### Téléchargement du jeu de données
# Le fichier zip contenant toutes les données fait 6GB

# %% [markdown]
# ### Imports

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# # Le fichier zip contenant toutes les données fait 6GB
# import h5py
# import matplotlib.pyplot as plt

# # Ouvrir le fichier HDF5 en mode lecture
# with h5py.File('4eme dataset/food_c101_n10099_r64x64x1.h5', 'r') as f:
#     # Lister toutes les clés du fichier
#     print("Keys: %s" % f.keys())
#     # Obtenir l'ensemble de données d'images
#     data = f['images']
#     # Créer une nouvelle figure avec une taille spécifique
#     plt.figure(figsize=(5, 5))

#     # Afficher la première image
#     plt.imshow(data[10098])
#     plt.show()
#     # Afficher la dimension de la première image
#     print("Image shape: ", data[1].shape)

# %% [markdown]
# #### Affichage des images

# %%
folder_path = '5eme dataset/images/waffles'

# Obtenir la liste de tous les fichiers dans le dossier
files = os.listdir(folder_path)

# Trier la liste des fichiers
files.sort()

# Obtenir le chemin complet du premier fichier
first_image_path = os.path.join(folder_path, files[0])

# Lire l'image
img = mpimg.imread(first_image_path)

# Afficher l'image
plt.imshow(img)
plt.show()
